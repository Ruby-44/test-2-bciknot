# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Ruby Hernandez**
# To be successful

# %% [markdown]
# *I am interested in data science because it just seems cool and I regreted not learning it during my undergrad.*

# %% [markdown]
# <h3>In cell 5 my code should add 1 and 1.<h3>

# %%
1+1
# Out:
# 2

# %% [markdown]
# <ol>
# <li>Numbered List</li>
# <li>Horizontal Rule</li>
# <li>Bulleted List</li>
# </ol>
#
# <hr>
# <ul>
# <li>This</li>
# <li>Is</li>
# <li>Cool</li>
# </ul>
#
# | Can | you |
# | ------ | ------ |
# | see | this |
#
# | it | is |
# | ------ | ------ |
#    | awesome |
